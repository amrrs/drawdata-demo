# %%
import seaborn as sns
import pandas as pd
sns.set_style("whitegrid")

# %%
df = pd.read_csv("~/Downloads/data.csv")

# %%
df
# Out:
#               x           y  z
# 0     47.901826   61.148189  a
# 1     58.525148  104.624170  a
# 2     51.666874   34.119420  a
# 3    169.543991   42.803704  a
# 4     99.273636   63.324250  a
# ..          ...         ... ..
# 200  466.197846  447.791623  c
# 201  510.577757  435.297882  c
# 202  424.582060  428.339121  c
# 203  494.131981  493.773130  c
# 204  484.016873  426.724906  c
#
# [205 rows x 3 columns]

# %%
sns.scatterplot(data= df, x = df.x, y = df.y, hue = df.z);
